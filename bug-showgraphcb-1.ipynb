# %%
from fastai.text.all import *

# %%
path = untar_data(URLs.IMDB_SAMPLE)
path.ls()
# Out:
# (#1) [Path('/home/user/.fastai/data/imdb_sample/texts.csv')]

# %%
df = pd.read_csv(path/'texts.csv')

# %%
df.shape
# Out:
# (1000, 3)

# %%
dfa = df[df['is_valid'] == True].iloc[:8,:]
dfb = df[df['is_valid'] == False].iloc[:8,:]
df2 = pd.concat((dfa, dfb))
df2.shape
# Out:
# (16, 3)

# %%
dbunch_lm = TextDataLoaders.from_df(df2, 
                                    text_col='text', 
                                    label_col='label', 
                                    path=path, 
                                    is_lm=True, 
                                    valid_col='is_valid',
                                     bs=4)
# Out:
# /home/user/anaconda3/envs/devfastai/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
learn = language_model_learner(dbunch_lm, AWD_LSTM, 
                               cbs = [ShowGraphCallback],
                              )

# %%
learn.fit(2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.648160</td>
#       <td>3.048818</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.622703</td>
#       <td>3.018979</td>
#       <td>00:12</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.predict("this movie was", 10, temperature=0.75)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/10 00:00<00:00]
#     </div>
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-19-f4ad1521e03a> in <module>
# ----> 1 learn.predict("this movie was", 10, temperature=0.75)
#
# ...

# %%
_ = learn.get_preds(ds_)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-5e21757c4f89> in <module>
# ----> 1 _ = learn.get_preds()
#
# /mnt/c/Users/wsutt/Desktop/files/fastai2-dev/sutt-dev-fastai-wsl/fastai/text/learner.py in get_preds(self, concat_dim, **kwargs)
#     179
#     180     @delegates(Learner.get_preds)
# --> 181     def get_preds(self, concat_dim=1, **kwargs): return super().get_preds(concat_dim=1, **kwargs)
#     182
#     183 # Cell
#
# /mnt/c/Users/wsutt/Desktop/files/fastai2-dev/sutt-dev-fastai-wsl/fastai/learner.py in get_preds(self, ds_idx, dl, with_input, with_decoded, with_loss, act, inner, reorder, cbs, **kwargs)
#     240                 res[pred_i] = act(res[pred_i])
#     241                 if with_decoded: res.insert(pred_i+2, getattr(self.loss_func, 'decodes', noop)(res[pred_i]))
# ...

# %% [markdown]
# #### Works?

# %%
learn2 = language_model_learner(dbunch_lm, AWD_LSTM, 
#                                cbs = [ShowGraphCallback],
                              )

learn2.fit(2)

learn2.predict("this movie was", 10, temperature=0.75)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.759779</td>
#       <td>3.048962</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.703929</td>
#       <td>3.018921</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# "this movie was Prince of 's Time , a film"

# %%
_ = learn2.get_preds(reorder=False)

# %%
_ = learn2.get_preds(reorder=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-c169954fdd5c> in <module>
# ----> 1 _ = learn2.get_preds(reorder=True)
#
# /mnt/c/Users/wsutt/Desktop/files/fastai2-dev/sutt-dev-fastai-wsl/fastai/text/learner.py in get_preds(self, concat_dim, **kwargs)
#     179
#     180     @delegates(Learner.get_preds)
# --> 181     def get_preds(self, concat_dim=1, **kwargs): return super().get_preds(concat_dim=1, **kwargs)
#     182
#     183 # Cell
#
# /mnt/c/Users/wsutt/Desktop/files/fastai2-dev/sutt-dev-fastai-wsl/fastai/learner.py in get_preds(self, ds_idx, dl, with_input, with_decoded, with_loss, act, inner, reorder, cbs, **kwargs)
#     240                 res[pred_i] = act(res[pred_i])
#     241                 if with_decoded: res.insert(pred_i+2, getattr(self.loss_func, 'decodes', noop)(res[pred_i]))
# ...
